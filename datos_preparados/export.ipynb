# %%
import pandas as pd

# %%
df = pd.read_excel('FOTOS.xlsx')

# %%
def completar(valor):
    valor = str(valor)
    return valor.zfill(2)

# %%
df['cod_depto']=df['cod_depto'].apply(completar)
df['cod_prov']=df['cod_prov'].apply(completar)
df['cod_mpio']=df['cod_mpio'].apply(completar)
df['concat'] = df['cod_depto']+df['cod_prov']+df['cod_mpio']

# %%
df = df[['concat','cod_depto', 'depto', 'cod_prov', 'prov', 'cod_mpio', 'mpio']]

# %%
df.to_csv('municipios.csv',sep=';',index=False)

# %%
df
# Out:
#      concat cod_depto       depto cod_prov            prov cod_mpio  \
# 0    010101        01  CHUQUISACA       01         OROPEZA       01
# 1    010102        01  CHUQUISACA       01         OROPEZA       02
# 2    010103        01  CHUQUISACA       01         OROPEZA       03
# 3    010201        01  CHUQUISACA       02         AZURDUY       01
# 4    010202        01  CHUQUISACA       02         AZURDUY       02
# ..      ...       ...         ...      ...             ...      ...
# 338  090401        09       PANDO       04           ABUNA       01
# 339  090402        09       PANDO       04           ABUNA       02
# 340  090501        09       PANDO       05  FEDERICO ROMAN       01
# 341  090502        09       PANDO       05  FEDERICO ROMAN       02
# 342  090503        09       PANDO       05  FEDERICO ROMAN       03
#
#                 mpio
# 0              SUCRE
# 1             YOTALA
# 2             POROMA
# 3            AZURDUY
# 4            TARVITA
# ...
